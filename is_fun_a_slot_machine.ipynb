# %%
# !pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emoji
#   Downloading emoji-2.1.0.tar.gz (216 kB)
#      |████████████████████████████████| 216 kB 24.8 MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.1.0-py3-none-any.whl size=212392 sha256=6e0c1efd79758d591dcf69fdc80d5f893894e60592e7049c3d9f2bb56978e8e9
#   Stored in directory: /root/.cache/pip/wheels/77/75/99/51c2a119f4cfd3af7b49cc57e4f737bed7e40b348a85d82804
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-2.1.0

# %%
from random import randint
from time import sleep
import emoji

# %%
def SimbolosPremios():
    simbolos = [':lady_beetle:', ':ant:', ':snail:', ':bug:']
    premios = [20, 15, 10, 5]
    return simbolos, premios

# %%
def Linhas(frase, simbolo = '*', cor = ''):
    print(cor, end = '')
    linha = (len(frase) + 2) * simbolo
    print('\n' + '\033[1m' + linha)
    print(' ' + frase)
    print(linha + '\033[0m')

# %%
def Suspense(e1, e2, e3):
    lista = ['\nAlavanca acionada!     ', e1, '.', '.', '. ', e2, '.', '.', '. ', e3+'!\n'] 
    for i in lista:
        print(i, end = '')
        sleep(0.7)

# %%
def Explicacao():
    simbs, premios = SimbolosPremios()
    sleep(1.5)
    print('-' * 70)
    print('\033[1m' + '\nRegras:\n' + '\033[0m')
    for i in range(len(simbs)): 
        print(emoji.emojize('Acerte ' + 3*simbs[i] + '  >>>>>  e ganhe {} fichas!'.format(premios[i]), language='alias'))
    print('\033[1m' + '\nBoa Sorte! Haha\n' + '\033[0m')

# %%
def Jogo():
    simbs, premios = SimbolosPremios() 
    s = len(simbs)

    s1 = randint(1, s) - 1
    s2 = randint(1, s) - 1
    s3 = randint(1, s) - 1

    Suspense(emoji.emojize(simbs[s1], language='alias'),# use_aliases = True), 
             emoji.emojize(simbs[s2], language='alias'),# use_aliases = True), 
             emoji.emojize(simbs[s3], language='alias'))#, use_aliases = True))  

    if simbs[s1] == simbs[s2] == simbs[s3]:
        premio = premios[simbs.index(simbs[s1])]
        Linhas('***** GANHOU! *****', '$', '\033[92m')
        print('\n' + '\033[1m' + 'Seu prêmio é de {} fichas!'.format(premio) + '\033[0m')
    else:
        print('\nNão foi dessa vez! :(')
        premio = 0
   
    return premio

# %%
def SlotMachine():
    nome = input('- Entre com o seu nome: ') 

    while True:
        fichas0 = input('- Quantas fichas você gostaria de comprar? ')
        if fichas0.isdigit():
            break
        else:
            print('\n**Entrada inválida** - Tente novamente.\n')

    fichas = int(fichas0)

    f1 = 'Seja muito bem-vindo, {}!'.format(nome)
    Linhas(f1.upper(), '*', '\033[94m')
 
    Explicacao()

    while fichas > 0:
        print('-' * 70)
        x = input('Aperte ENTER para puxar a alavanca ou digite SAIR para ir embora. ')

        if x.lower() == 'sair':
            print('-' * 70)
            Linhas('Fim de jogo! Você saiu com um total de {} fichas!'.format(fichas), '*', '\033[94m') 
            break  
        else:
            jogo = Jogo()
            fichas += jogo -1
            print('\nSeu saldo atual é de fichas é {}'.format(fichas))
    else:
        print('-' * 80)
        Linhas('Fim de jogo! Suas fichas acabaram! Até a próxima! Haha', '*', '\033[94m')

# %%
SlotMachine()
# Out:
# - Entre com o seu nome: Leandro Neri da Silva
# - Quantas fichas você gostaria de comprar? 5
#
# **********************************************
#  SEJA MUITO BEM-VINDO, LEANDRO NERI DA SILVA!
# **********************************************
# ----------------------------------------------------------------------
#
# Regras:
#
# Acerte 🐞🐞🐞  >>>>>  e ganhe 20 fichas!
# Acerte 🐜🐜🐜  >>>>>  e ganhe 15 fichas!
# Acerte 🐌🐌🐌  >>>>>  e ganhe 10 fichas!
# Acerte 🐛🐛🐛  >>>>>  e ganhe 5 fichas!
#
# Boa Sorte! Haha
#
# ----------------------------------------------------------------------
# Aperte ENTER para puxar a alavanca ou digite SAIR para ir embora.
#
# Alavanca acionada!     🐌... 🐛... 🐛!
#
# Não foi dessa vez! :(
#
# Seu saldo atual é de fichas é 4
# ----------------------------------------------------------------------
# Aperte ENTER para puxar a alavanca ou digite SAIR para ir embora.
#
# Alavanca acionada!     🐞... 🐛... 🐞!
#
# Não foi dessa vez! :(
#
# Seu saldo atual é de fichas é 3
# ----------------------------------------------------------------------
# Aperte ENTER para puxar a alavanca ou digite SAIR para ir embora.
#
# Alavanca acionada!     🐞... 🐛... 🐌!
#
# Não foi dessa vez! :(
#
# Seu saldo atual é de fichas é 2
# ----------------------------------------------------------------------
# Aperte ENTER para puxar a alavanca ou digite SAIR para ir embora.
#
# Alavanca acionada!     🐛... 🐞... 🐛!
#
# Não foi dessa vez! :(
#
# Seu saldo atual é de fichas é 1
# ----------------------------------------------------------------------
# Aperte ENTER para puxar a alavanca ou digite SAIR para ir embora.
#
# Alavanca acionada!     🐞... 🐌... 🐞!
#
# Não foi dessa vez! :(
#
# Seu saldo atual é de fichas é 0
# --------------------------------------------------------------------------------
#
# ********************************************************
#  Fim de jogo! Suas fichas acabaram! Até a próxima! Haha
# ********************************************************
